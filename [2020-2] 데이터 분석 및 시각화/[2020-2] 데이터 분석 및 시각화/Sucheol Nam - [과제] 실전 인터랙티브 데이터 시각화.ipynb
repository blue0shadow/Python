# %% [markdown]
# # 실전 인터랙티브 데이터 시각화
#
# 분석할 데이터를 읽고, Bokeh 라이브러리를 사용하여 다양한 인터랙티브 시각화 만들기

# %% [markdown]
# + 공공데이터 포털 : 20200225일 기준 성남시 동별 인구수 csv파일 이용
# + 성남시내 3개 구내 구별,동별 인구수 분석

# %% [markdown]
# ## 데이터 파일 읽기

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.plotting import figure , show
output_notebook()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pop = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/20200225.csv",encoding='euc-kr')
pop.head()
# Out:
#     구별              동  인구수_계  인구수_남  ...  65세 이상_남자  65세 이상_여자   세대수  재외국민
# 0  수정구  신흥1동           13659   7098  ...       1039       1398  7763     9
# 1  수정구  신흥2동            9906   4893  ...        695        788  3801    14
# 2  수정구  신흥3동           11140   5792  ...        828       1088  6172     8
# 3  수정구  태평1동           15870   8042  ...       1266       1659  8604    26
# 4  수정구  태평2동           16111   8071  ...       1124       1553  7805    19
#
# [5 rows x 13 columns]

# %% [markdown]
# ## 인터랙티브 데이터 시각화

# %% [markdown]
# **성남시 구별 인구수 분석**

# %%
location = ["분당구", "수정구", "중원구"]
A = pop.groupby(by=['구별'], as_index=False)["인구수_계"].sum()
A
# Out:
#     구별   인구수_계
# 0  분당구  488114
# 1  수정구  234614
# 2  중원구  219921

# %%
p = figure(x_range = A["구별"], plot_width = 800, plot_height = 600, title = "성남시 구별 인구수" y_axis_type = "log")
p.line(A["구별"], A["인구수_계"], line_width = 2,legend_label="인구수")
p.xgrid.grid_line_color =None
p.xaxis.axis_label = "구"
p.yaxis.axis_label = "인구수" 
show(p)
# Out:
#   <div class="bk-root" id="380f8f19-3f55-4f28-b105-3417e921e670" data-root-id="36907"></div>

# %%
labels_bd = pop[pop["구별"] == "분당구"]
labels_bd = labels_bd.iloc[:, 1:3]
labels_bd.head()

# %%
p = figure(plot_width = 800, plot_height = 600)
p.hex(pop["인구수_남"], pop["인구수_여"], size = pop["재외국민"]/10, color = "darkblue", alpha = 0.5,legend_label="재외국민")
p.xaxis.axis_label = "인구수_남"
p.yaxis.axis_label = "인구수_여"
show(p)
# Out:
#   <div class="bk-root" id="4f180000-631c-47fd-8931-e75561d48a10" data-root-id="20105"></div>

# %%
labels_bd = pop[pop["구별"] == "분당구"]
labels_bd = labels_bd.iloc[:, 1:3]
labels_bd.head()
# Out:
#                 동  인구수_계
# 28  분당동            26840
# 29  수내1동           18185
# 30  수내2동           10825
# 31  수내3동           14401
# 32  정자동            20113

# %%
labels_bd["동"].head()
# Out:
# 28    분당동
# 29    수내1동
# 30    수내2동
# 31    수내3동
# 32    정자동
# Name: 동, dtype: object

# %%
p = figure(x_range = labels_bd["동"], plot_height = 600,plot_width = 1500, title = "분당구 동별 인구수")
p.line( labels_bd["동"] , labels_bd["인구수_계"] , line_width = 2,legend_label="인구수")
p.xgrid.grid_line_color =None
p.xaxis.axis_label = "동"
p.yaxis.axis_label = "인구수"         
show(p);
# Out:
#   <div class="bk-root" id="c0fab39b-edf9-4562-b7b6-f6561ddc77a6" data-root-id="28165"></div>

# %%
p.scatter( labels_bd["동"] , labels_bd["인구수_계"] , line_width = 2,legend_label="인구수")
show(p)
# Out:
#   <div class="bk-root" id="b2c6842d-177e-47fa-9699-27a642389046" data-root-id="25122"></div>

# %%
labels_sj = pop[pop["구별"] == "수정구"]
labels_sj = labels_sj.iloc[:, 0:3]
labels_sj.head()
# Out:
#     구별              동  인구수_계
# 0  수정구  신흥1동           13659
# 1  수정구  신흥2동            9906
# 2  수정구  신흥3동           11140
# 3  수정구  태평1동           15870
# 4  수정구  태평2동           16111

# %%
p = figure(x_range = labels_sj["동"], plot_height = 600,plot_width = 1500, title = "수정구 동별 인구수")
#p.line( labels_sj["동"] , labels_sj["인구수_계"] , line_width = 2,legend_label="인구수")
p.hex(labels_sj["동"] , labels_sj["인구수_계"] ,  size = labels_sj["인구수_계"]/500, color = "purple", alpha = 0.3, legend_label="인구수/500")
p.xgrid.grid_line_color =None
p.xaxis.axis_label = "동"
p.yaxis.axis_label = "인구수"         
show(p);
# Out:
#   <div class="bk-root" id="0bad1cd9-ff81-4be5-9a0a-7977c456e6de" data-root-id="46881"></div>

# %%
labels_gw = pop[pop["구별"] == "중원구"]
labels_gw = labels_gw.iloc[:, 0:3]
labels_gw.head()
# Out:
#      구별              동  인구수_계
# 17  중원구  성남동            33477
# 18  중원구  중앙동            14412
# 19  중원구  금광1동            7199
# 20  중원구  금광2동           25331
# 21  중원구  은행1동           11029

# %%
p = figure(x_range = labels_gw["동"], plot_height = 600,plot_width = 1500, title = "중원구 동별 인구수")
p.line( labels_gw["동"] , labels_gw["인구수_계"] , line_width = 2,legend_label="인구수")
p.xgrid.grid_line_color =None
p.xaxis.axis_label = "동"
p.yaxis.axis_label = "인구수"         
show(p);
# Out:
#   <div class="bk-root" id="5579d152-8509-45fe-9c9f-32d393c59f15" data-root-id="24469"></div>
