# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# ### 표준 입력 함수

# %%
name = input("이름: ")
print(name)
# Out:
# 이름: 남수철
# 남수철

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
celsius = float(input("섭씨온도 : "))
fahrenheit = (celsius*1.8)+32
print("화씨온도 :",fahrenheit)
# Out:
# 섭씨온도 : 21.2
# 화씨온도 : 70.16

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
i = int(input("출력할 단: "))
for j in range(1,10):
  print("{0} x {1} = {2}".format(i,j,i * j) )
# Out:
# 출력할 단: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %% [markdown]
# ### 표준 출력 함수

# %%
print("Hello Python")
print("안녕 파이썬")
print(7)
print(3.14)
print([1,2,3])

print("Hello", "Python", sep = "---")
print(1,2,3)
print(1, end=' ') # end끝에 출력할 항목 지정 , 기본값은 \n
print(2, end=' ')
print(3, end=' ')
# Out:
# Hello Python
# 안녕 파이썬
# 7
# 3.14
# [1, 2, 3]
# Hello---Python
# 1 2 3
# 1 2 3

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2,10):
  for j in range(1,10):
    print("{0}x{1}={2}".format(i,j,i*j),end="\t")
  print()
# Out:
# 2x1=2	2x2=4	2x3=6	2x4=8	2x5=10	2x6=12	2x7=14	2x8=16	2x9=18
# 3x1=3	3x2=6	3x3=9	3x4=12	3x5=15	3x6=18	3x7=21	3x8=24	3x9=27
# 4x1=4	4x2=8	4x3=12	4x4=16	4x5=20	4x6=24	4x7=28	4x8=32	4x9=36
# 5x1=5	5x2=10	5x3=15	5x4=20	5x5=25	5x6=30	5x7=35	5x8=40	5x9=45
# 6x1=6	6x2=12	6x3=18	6x4=24	6x5=30	6x6=36	6x7=42	6x8=48	6x9=54
# 7x1=7	7x2=14	7x3=21	7x4=28	7x5=35	7x6=42	7x7=49	7x8=56	7x9=63
# 8x1=8	8x2=16	8x3=24	8x4=32	8x5=40	8x6=48	8x7=56	8x8=64	8x9=72
# 9x1=9	9x2=18	9x3=27	9x4=36	9x5=45	9x6=54	9x7=63	9x8=72	9x9=81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
f = open("file.txt",'w')
f = open("file.txt",'r')
f.close()

# %%
# !ls file.txt
# Out:
# file.txt

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f = open("file.txt",'w')
f.write("Hello python")
f.close()

# %%
# !cat file.txt
# Out:
# Hello python

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
list = ["One\n","Two\n","Three\n"]
f=open("file.txt",'w')
f.writelines(list)
f.close()

# %%
# !cat file.txt
# Out:
# one
# Two
# Three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
text = input("입력: ")
f = open("file.txt",'w')
f.write(text)
f.close()
# Out:
# 입력: 남수철

# %%
# !cat file.txt
# Out:
# 남수철

# %%
text = [str(text + '\n')for text in input("여러값 입력: ").split()]
f = open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 여러값 입력: 1 2 3 4 5

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x= ""
text = ""
while x != 'q':
  x = input("반복 입력 : ")
  text += x +'\n'
f = open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 반복 입력 : 1
# 반복 입력 : 2
# 반복 입력 : 3
# 반복 입력 : 4
# 반복 입력 : 5
# 반복 입력 : q

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open("dan.txt",'w')
for i in range(2,10):
  for j in range(1,10):
    f.write("{0}x{1}={2}\n".format(i,j,i*j))
  else:
    f.write("\n")
f.close()

# %%
# !cat dan.txt
# Out:
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
#
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
#
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
#
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
#
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
#
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
#
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
#
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# * 텍스트 파일 예제

# %%
# !echo "동해물과 백두산이 마르고 닳도록" > anthem.txt
# !echo "하느님이 보우하사 우리나라 만세" >> anthem.txt  #append로 붙일떄

# %% [markdown]
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f =  open("anthem.txt",'r')
while True:
  line = f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f = open("anthem.txt",'r')
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록\n', '하느님이 보우하사 우리나라 만세\n']

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f = open("anthem.txt",'r')
data  = f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f = open("anthem.txt",'r')
while True:
  print(f.tell())
  line = f.readline()
  if not line:break
  print(line)
f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록
#
# 46
# 하느님이 보우하사 우리나라 만세
#
# 92

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
f = open("anthem.txt",'r')
f.seek(46)
line = f.readline()
print(line)

f.seek(0)
line = f.readline()
print(line)

f.close()
# Out:
# 하느님이 보우하사 우리나라 만세
#
# 동해물과 백두산이 마르고 닳도록

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f = open("file.txt",'w')
f.write("Hello Python")
f.close()

# %%
with open("file.txt",'w') as f:
  f.write("Hello Python")

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f = open("file.txt",'w')
line =""
while True:
  line = input()
  if not line: break
  f.writelines(line + '\n')

f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %%
# !cat file.txt
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4db1c280-c947-43c1-9135-38565f661bc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4db1c280-c947-43c1-9135-38565f661bc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KakaoTalk_20200724_155300136.jpg to KakaoTalk_20200724_155300136.jpg
# {'KakaoTalk_20200724_155300136.jpg': b'\xff\xd8\xff\xe1\x02\xe9Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x0c\x01\x00\x00\x04\x00\x00\x00\x01\x00\x00\x0f\xc0\x01\x10\x00\x02\x00\x00\x00\t\x00\x00\x00\x9e\x01\x01\x00\x04\x00\x00\x00\x01\x00\x00\x0b\xd0\x011\x00\x02\x00\x00\x00\x0e\x00\x00\x00\xa7\x01\x12\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xb5\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xe1\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\xc9\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\xd1\x01\x0f\x00\x02\x00\x00\x00\x08\x00\x00\x00\xd9\x00\x00\x02\x83SM-N976Q\x00N976QXXU3CTE4\x002020:07:24 15:52:51\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\
xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfd4W\x04\xf7\xafp ...

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  KakaoTalk_20200724_155300136.jpg  sample_data

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input  = open("KakaoTalk_20200724_155300136.jpg",'rb')
output = open("KakaoTalk_20200724_155300136_copy.jpg",'wb')
while True:
  fp = input.read(1)
  if not fp: break
  output.write(fp)

input.close()
output.close()

# %%
# !ls
# Out:
# anthem.txt  KakaoTalk_20200724_155300136_copy.jpg  test
# dan.txt     KakaoTalk_20200724_155300136.jpg
# file.txt    sample_data

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
import os
import shutil
os.mkdir('test')
os.mkdir('test/1')
os.mkdir('test/2')
os.mkdir('test/3')

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data
# dan.txt     KakaoTalk_20200724_155300136.jpg  test

# %%
# !ls test
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy('KakaoTalk_20200724_155300136.jpg','KakaoTalk_20200724_155300136_copy2.jpg')
# Out:
# 'KakaoTalk_20200724_155300136_copy2.jpg'

# %%
# !ls
# Out:
# anthem.txt  KakaoTalk_20200724_155300136_copy2.jpg  sample_data
# dan.txt     KakaoTalk_20200724_155300136_copy.jpg   test
# file.txt    KakaoTalk_20200724_155300136.jpg

# %%
import shutil
shutil.copytree('test','test2')
# Out:
# 'test2'

# %%
# !ls
# Out:
# anthem.txt  KakaoTalk_20200724_155300136_copy2.jpg  sample_data
# dan.txt     KakaoTalk_20200724_155300136_copy.jpg   test
# file.txt    KakaoTalk_20200724_155300136.jpg	    test2

# %%
# !ls test2
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir('test'))
print(os.path.isdir('test/1'))
print(os.path.isdir('test/4'))
print(os.path.isfile('KakaoTalk_20200724_155300136.jpg'))
print(os.path.isfile('KakaoTalk_20200724_155300136_copy.jpg'))
print(os.path.isfile('KakaoTalk_20200724_155300136_copy2.jpg'))
print(os.path.exists('test2'))
print(os.path.exists('test2/1'))
print(os.path.exists('test2/4'))
# Out:
# True
# True
# False
# True
# True
# True
# True
# True
# False

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list, file_names in os.walk('./'):
  for file_name in file_names:
    print(os.path.join(dir_name,file_name))
# Out:
# ./anthem.txt
# ./KakaoTalk_20200724_155300136_copy.jpg
# ./file.txt
# ./dan.txt
# ./KakaoTalk_20200724_155300136.jpg
# ./KakaoTalk_20200724_155300136_copy2.jpg
# ./.config/.last_opt_in_prompt.yaml
# ./.config/active_config
# ./.config/config_sentinel
# ./.config/.last_survey_prompt.yaml
# ./.config/.last_update_check.json
# ./.config/gce
# ./.config/.metricsUUID
# ./.config/configurations/config_default
# ./.config/logs/2020.07.10/16.29.12.848063.log
# ./.config/logs/2020.07.10/16.28.57.265459.log
# ./.config/logs/2020.07.10/16.28.19.621895.log
# ./.config/logs/2020.07.10/16.28.38.231204.log
# ./.config/logs/2020.07.10/16.28.52.396365.log
# ./.config/logs/2020.07.10/16.29.12.134415.log
# ./sample_data/anscombe.json
# ./sample_data/README.md
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os
os.remove('KakaoTalk_20200724_155300136_copy2.jpg')
os.remove('KakaoTalk_20200724_155300136_copy.jpg')

# %%
# !ls
# Out:
# anthem.txt  file.txt			      sample_data  test2
# dan.txt     KakaoTalk_20200724_155300136.jpg  test

# %%
import shutil
shutil.rmtree('test')
shutil.rmtree('test2')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  KakaoTalk_20200724_155300136.jpg  sample_data

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('KakaoTalk_20200724_155300136.jpg'))
print(os.path.getsize('file.txt'))
# Out:
# 0
# 92

# %% [markdown]
# ### 파일 압축

# %%
import zipfile
comp = zipfile.ZipFile('new.zip','w')
comp.write('KakaoTalk_20200724_155300136.jpg')
comp.close()

# %%
# !ls
# Out:
# anthem.txt  file.txt			      new.zip
# dan.txt     KakaoTalk_20200724_155300136.jpg  sample_data

# %%
decomp = zipfile.ZipFile('new.zip','r')
decomp.extractall('new')
decomp.close()

# %%
# !ls new
# Out:
# KakaoTalk_20200724_155300136.jpg
